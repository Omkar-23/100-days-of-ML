# %%
import pandas as pd
import numpy as np

# %%
#value_counts
stud = {
    'name':['ankit','abhi','omkar','snake'],
    'iq': [100,80,80,80],
    'marks':[80,70,70,70],
    'package':[8,12,2,np.NaN],
}

Stud = pd.DataFrame(stud)
Stud['marks'].value_counts()
# Out:
# marks
# 70    3
# 80    1
# Name: count, dtype: int64

# %%
ipl  = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[~ ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
(ipl['Team1'].value_counts()+ipl['Team2'].value_counts()).sort_values(ascending = False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
movies = pd.read_csv('/content/movies.csv')

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.sort_values('imdb_rating', ascending = False)
# Out:
#                          title_x    imdb_id  \
# 41          Family of Thakurganj  tt8897986
# 1628                    Humsafar  tt2403201
# 62                Saand Ki Aankh  tt8108206
# 1435  Final Solution (2003 film)  tt0402178
# 58             Ghost (2019 film)  tt9378950
# ...                          ...        ...
# 70     Keep Safe Distance (film)  tt8876008
# 331           Ek Kahani Julie Ki  tt7997334
# 479         Anuradha (2014 film)  tt3482198
# 407                  I Love Desi  tt4718678
# 236      Babuji Ek Ticket Bambai  tt7881528
#
#                                             poster_path  \
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 62    https://upload.wikimedia.org/wikipedia/en/thum...
# 1435                                                NaN
# 58    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
# na _position
# when sort_values is used NA values are placed at the end of the newly created Dataframe/Series
# to modify this behaviour we can use this na_position = False forcing na values to appear at first
movies.sort_values('imdb_rating', ascending = False, na_position = 'first')
# Out:
#                          title_x    imdb_id  \
# 41          Family of Thakurganj  tt8897986
# 1628                    Humsafar  tt2403201
# 62                Saand Ki Aankh  tt8108206
# 1435  Final Solution (2003 film)  tt0402178
# 58             Ghost (2019 film)  tt9378950
# ...                          ...        ...
# 70     Keep Safe Distance (film)  tt8876008
# 331           Ek Kahani Julie Ki  tt7997334
# 479         Anuradha (2014 film)  tt3482198
# 407                  I Love Desi  tt4718678
# 236      Babuji Ek Ticket Bambai  tt7881528
#
#                                             poster_path  \
# 41    https://upload.wikimedia.org/wikipedia/en/9/99...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 62    https://upload.wikimedia.org/wikipedia/en/thum...
# 1435                                                NaN
# 58    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
#sorting using multiple cols

movies.sort_values(['year_of_release', 'title_x'],ascending= [True, False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
bats = pd.read_csv('/content/batsman_runs_ipl.csv')

# %%
# Rank only applicable on series
# same values will result in the same rank being assigned to those rows
# check last 2 rows
bats['Rank'] = bats['batsman_run'].rank(ascending = False)
bats.sort_values('Rank')
# Out:
#            batter  batsman_run   Rank
# 569       V Kohli         6634    1.0
# 462      S Dhawan         6244    2.0
# 130     DA Warner         5883    3.0
# 430     RG Sharma         5881    4.0
# 493      SK Raina         5536    5.0
# ..            ...          ...    ...
# 512   SS Cottrell            0  594.0
# 466     S Kaushik            0  594.0
# 203     IC Pandey            0  594.0
# 467       S Ladda            0  594.0
# 468  S Lamichhane            0  594.0
#
# [605 rows x 3 columns]

# %%
# Sorting on the basis of index
Stud
# Out:
#     name   iq  marks  package
# 0  ankit  100     80        8
# 1   abhi   80     70       12
# 2  omkar   80     70        2
# 3  snake   80     70        2

# %%
Stud.sort_index(ascending  = False)
# Out:
#     name   iq  marks  package
# 3  snake   80     70        2
# 2  omkar   80     70        2
# 1   abhi   80     70       12
# 0  ankit  100     80        8

# %%
#set_index Dataframes only

bats.set_index('batter', inplace = True)

# %%
# reset index

bats.reset_index().set_index('Rank')
# Out:
#                batter  batsman_run
# Rank
# 166.5  A Ashish Reddy          280
# 226.0        A Badoni          161
# 535.0      A Chandila            4
# 329.0        A Chopra           53
# 402.5     A Choudhary           25
# ...               ...          ...
# 594.0      Yash Dayal            0
# 343.0   Yashpal Singh           47
# 547.5     Younis Khan            3
# 27.0     Yuvraj Singh         2754
# 256.0          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# # when reset_index() is used on the dataframe it auto converts Dataframe to Series

# %%
#rename

bats.rename(columns  = {'batter': 'Batsman' , 'Rank':'Bat_rank'}, inplace = True)

# %%
bats.rename(index = {'A Badoni': 'A_Badoni'})
# Out:
#                 batsman_run  Bat_rank
# batter
# A Ashish Reddy          280     166.5
# A_Badoni                161     226.0
# A Chandila                4     535.0
# A Chopra                 53     329.0
# A Choudhary              25     402.5
# ...                     ...       ...
# Yash Dayal                0     594.0
# Yashpal Singh            47     343.0
# Younis Khan               3     547.5
# Yuvraj Singh           2754      27.0
# Z Khan                  117     256.0
#
# [605 rows x 2 columns]

# %%
#unique
# returns all the unique values from the Series
# also counts missing values as an entity
ipl['Season'].unique()

# to count unique values

ipl['Season'].nunique() # returns the count of all the seasons of ipl


# nunique doesn't count NaN values
# Out:
# 15

# %%
ipl.isnull()
ipl.notnull()
# Out:
#        ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0    True  True  True    True         True   True   True   True        True
# 1    True  True  True    True         True   True   True   True        True
# 2    True  True  True    True         True   True   True   True        True
# 3    True  True  True    True         True   True   True   True        True
# 4    True  True  True    True         True   True   True   True        True
# ..    ...   ...   ...     ...          ...    ...    ...    ...         ...
# 945  True  True  True    True         True   True   True   True        True
# 946  True  True  True    True         True   True   True   True        True
# 947  True  True  True    True         True   True   True   True        True
# 948  True  True  True    True         True   True   True   True        True
# 949  True  True  True    True         True   True   True   True        True
#
# ...

# %%
# hasnans
movies['genres'].hasnans
# Out:
# False

# %%
# dropna

movies.dropna(how = 'any')
movies.dropna(how = 'all')    # remove the row if and only if the entire row is NaN
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#dropping wrt to a colmn
movies.dropna(subset = ['title_x'])
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(subset = ['imdb_rating', 'imdb_votes'])
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# fillna
Stud
# Out:
#     name   iq  marks  package
# 0  ankit  100     80      8.0
# 1   abhi   80     70     12.0
# 2  omkar   80     70      2.0
# 3  snake   80     70      NaN

# %%
Stud['package'].fillna(Stud['package'].mean())
# Out:
# 0     8.000000
# 1    12.000000
# 2     2.000000
# 3     7.333333
# Name: package, dtype: float64

# %%
#methods of filling

Stud['package'].fillna(method = 'ffill') # previous value is filled in to the current place

Stud['package'].fillna(method = 'bfill')
# Out:
# 0     8.0
# 1    12.0
# 2     2.0
# 3     2.0
# Name: package, dtype: float64

# %%
movies.drop_duplicates(keep = 'last')
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#drop columns
movies.drop(columns = ['imdb_id','poster_path'])
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                               wiki_link  \
# 0     https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1           https://en.wikipedia.org/wiki/Battalion_609
# 2     https://en.wikipedia.org/wiki/The_Accidental_P...
# 3         https://en.wikipedia.org/wiki/Why_Cheat_India
# 4         https://en.wikipedia.org/wiki/Evening_Shadows
# ...                                                 ...
# ...

# %%
#dropping rows

Stud

Stud.drop(index =[3,2])
# Out:
#     name   iq  marks  package
# 0  ankit  100     80      8.0
# 1   abhi   80     70     12.0
