# %%
import pandas as pd
import numpy as np

# %%
#methhods .head and .tail returms the view of the data not the copy
#so if the changes are made referencing them.. it will also change the values from df or series
vk=pd.read_csv('/content/kohli_ipl.csv').squeeze()
s1 = pd.read_csv('/content/bollywood.csv').squeeze()

# %%
#Typecasting
s0.astype('int16')
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
#Between- Returns boolean series
vk['runs'].between(51,99)
#both inclusive
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 210    False
# 211    False
# 212     True
# 213    False
# 214    False
# Name: runs, Length: 215, dtype: bool

# %%
#clip
vk.clip(60,70)
#clips the range of the numbers where the values lower than the min value is
#converted to the lower bound and same for upper bound
# Out:
#      match_no  runs
# 0          60    60
# 1          60    60
# 2          60    60
# 3          60    60
# 4          60    60
# ..        ...   ...
# 210        70    60
# 211        70    60
# 212        70    70
# 213        70    60
# 214        70    60
#
# [215 rows x 2 columns]

# %%
#drop_duplicates
#first occurance is kept and rest is kept by default
temp = pd.Series([1,2,1,2,3,4,5,6])
temp.drop_duplicates()
temp.drop_duplicates(keep = 'last')# keeps the last occurances rest is removed
# Out:
# 2    1
# 3    2
# 4    3
# 5    4
# 6    5
# 7    6
# dtype: int64

# %%
#returns true if there are duplicate elements
temp.duplicated()
temp.duplicated().sum()
# Out:
# 2

# %%
#drop_duplicates
temp.drop_duplicates()
# Out:
# 0    1
# 1    2
# 4    3
# 5    4
# 6    5
# 7    6
# dtype: int64

# %%
temp = pd.Series([1,2,1,2,3,4,5,6,np.nan,np.nan])
temp.count() #doesn't count null values
# Out:
# 8

# %%
temp.isnull()#returns the boolean array
# Out:
# 2

# %%
temp.dropna()#drops the missing values
# Out:
# 0    1.0
# 1    2.0
# 2    1.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    5.0
# 7    6.0
# dtype: float64

# %%
temp.fillna(0)#missing values will be filled with 0
temp.fillna(temp.mean())#mean imputation
# Out:
# 0    1.0
# 1    2.0
# 2    1.0
# 3    2.0
# 4    3.0
# 5    4.0
# 6    5.0
# 7    6.0
# 8    3.0
# 9    3.0
# dtype: float64

# %%
# isin
vk[vk.isin([69,22,4])]
# Out:
#      match_no  runs
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         4.0   NaN
# 4         NaN   NaN
# ..        ...   ...
# 210       NaN   NaN
# 211       NaN   NaN
# 212       NaN   NaN
# 213       NaN   NaN
# 214       NaN   NaN
#
# [215 rows x 2 columns]

# %%
#apply- user defined functions can be defined to execute on series
s1["movie"].apply(lambda x: x.split())
# Out:
# 0                    [Uri:, The, Surgical, Strike]
# 1                                 [Battalion, 609]
# 2       [The, Accidental, Prime, Minister, (film)]
# 3                              [Why, Cheat, India]
# 4                               [Evening, Shadows]
#                            ...
# 1495                   [Hum, Tumhare, Hain, Sanam]
# 1496                       [Aankhen, (2002, film)]
# 1497                            [Saathiya, (film)]
# 1498                             [Company, (film)]
# 1499                      [Awara, Paagal, Deewana]
# Name: movie, Length: 1500, dtype: object

# %%
# vk.apply(lambda X: 'good' if x> vk.mean()else 'bad')
vk.apply(lambda x: 'good' if x> vk.mean()else 'bad')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6d7fe5f4b571> in <cell line: 2>()
#       1 # vk.apply(lambda X: 'good' if x> vk.mean()else 'bad')
# ----> 2 vk.apply(lambda x: 'good' if x> vk.mean()else 'bad')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# ...

# %%
#copy
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
new = vk.head()
new
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
new [0] = 12

vk.head().copy()#creates a copy to avoid unnecessary changes to the orignal dataframe/series
# Out:
# <ipython-input-57-8364b846250f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new [0] = 12
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1
